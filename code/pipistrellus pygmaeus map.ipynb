# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\programdata\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from geopandas) (20.9)
# Requirement already satisfied: fiona>=1.8 in c:\programdata\anaconda3\lib\site-packages (from geopandas) (1.8.22)
# Requirement already satisfied: pyproj>=2.6.1.post1 in c:\programdata\anaconda3\lib\site-packages (from geopandas) (3.3.1)
# Requirement already satisfied: pandas>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from geopandas) (1.2.4)
# Requirement already satisfied: shapely>=1.7 in c:\programdata\anaconda3\lib\site-packages (from geopandas) (1.8.2)
# Requirement already satisfied: click>=4.0 in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2020.12.5)
# Requirement already satisfied: click-plugins>=1.0 in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: six>=1.7 in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: munch in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (52.0.0.post20210125)
# Requirement already satisfied: attrs>=17 in c:\programdata\anaconda3\lib\site-packages (from fiona>=1.8->geopandas) (20.3.0)
# Requirement already satisfied: numpy>=1.16.5 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=1.0.0->geopandas) (2021.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->geopandas) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
import os
import numpy as np

# %%
world_urban = gpd.read_file("ne_10m_urban_areas")
#world_cities = gpd.read_file("ne_10m_populated_places_simple")

# %%
world_urban
# Out:
#        scalerank  featurecla  area_sqkm  min_zoom  \
# 0              9  Urban area     12.581       7.7
# 1              5  Urban area    111.989       5.0
# 2              8  Urban area     46.348       7.6
# 3              8  Urban area     46.058       7.6
# 4              7  Urban area     84.596       7.0
# ...          ...         ...        ...       ...
# 11873          9  Urban area     10.257       7.7
# 11874          9  Urban area     22.154       7.7
# 11875          3  Urban area    423.111       3.7
# 11876          5  Urban area    169.475       5.0
# 11877          7  Urban area     24.661       7.0
#
#                                                 geometry
# 0      POLYGON ((-1.65718 37.38898, -1.65718 37.38258...
# 1      POLYGON ((-2.44605 36.97791, -2.38020 36.84286...
# 2      POLYGON ((-3.14629 36.78131, -3.14586 36.77794...
# 3      POLYGON ((-3.47237 36.74392, -3.48243 36.69927...
# 4      POLYGON ((-4.81597 36.50886, -4.81470 36.50254...
# ...                                                  ...
# 11873  POLYGON ((128.03624 45.91095, 128.03623 45.910...
# 11874  POLYGON ((123.19482 45.81154, 123.17305 45.811...
# 11875  POLYGON ((126.77642 45.73809, 126.78344 45.722...
# 11876  POLYGON ((130.98280 45.81131, 130.98750 45.810...
# 11877  POLYGON ((130.57002 45.71825, 130.57002 45.718...
#
# [11878 rows x 5 columns]

# %%
bbox = (7, 45, 8.0, 46)

bats_bbox = np.array([[7.6, 45.4], [7.6,45.6],[7.1, 45.6],[7.1, 45.4]])

# Filter data within the bounding box
ppy_urban = world_urban.cx[bbox[0]:bbox[2], bbox[1]:bbox[3]]
#ppy_cities = world_cities.cx[bbox[0]:bbox[2], bbox[1]:bbox[3]]

# %%
print([bbox[0],bbox[2]])
# Out:
# [7, 8.0]

# %%
ppy_urban
# Out:
#       scalerank  featurecla  area_sqkm  min_zoom  \
# 8144          8  Urban area     52.465       7.6
# 8150          8  Urban area     32.486       7.6
# 8160          9  Urban area      9.594       7.7
# 8163          9  Urban area     14.830       7.7
# 8165          7  Urban area     33.499       7.0
# 8173          9  Urban area     10.278       7.7
# 8175          8  Urban area     51.807       7.6
# 8178          9  Urban area     13.848       7.7
# 8185          7  Urban area     96.413       7.0
# 8189          9  Urban area     20.680       7.7
# 8203          8  Urban area     34.694       7.6
# 8222          9  Urban area     23.066       7.7
# 8238          5  Urban area    103.738       5.0
# 8268          9  Urban area     11.433       7.7
# 8272          8  Urban area     25.768       7.6
# 9112          4  Urban area   1170.657       4.0
#
#                                                geometry
# 8144  POLYGON ((7.64115 45.85320, 7.66482 45.80454, ...
# 8150  POLYGON ((7.07591 45.82698, 7.09690 45.81147, ...
# 8160  POLYGON ((7.42533 45.79080, 7.41849 45.78357, ...
# 8163  POLYGON ((7.24122 45.68915, 7.24121 45.68915, ...
# 8165  POLYGON ((7.30200 45.71405, 7.29014 45.71376, ...
# 8173  POLYGON ((7.70776 45.65582, 7.68818 45.65558, ...
# 8175  POLYGON ((7.37940 45.60395, 7.36206 45.60285, ...
# 8178  POLYGON ((7.80650 45.58173, 7.80649 45.58173, ...
# 8185  POLYGON ((7.94179 45.45877, 7.94121 45.44476, ...
# 8189  POLYGON ((7.01573 45.46718, 7.01572 45.46718, ...
# 8203  POLYGON ((7.69670 45.37815, 7.70151 45.37755, ...
# 8222  POLYGON ((8.01274 45.25517, 8.01894 45.23364, ...
# 8238  POLYGON ((7.23071 45.19827, 7.22973 45.19147, ...
# 8268  POLYGON ((7.35361 45.02289, 7.34116 45.02248, ...
# 8272  POLYGON ((8.02999 44.95583, 8.02998 44.95582, ...
# 9112  POLYGON ((7.58566 45.26700, 7.59618 45.26680, ...

# %%
fig, ax = plt.subplots()

# Plot the filtered geographic data

bats_area = Polygon(bats_bbox, edgecolor="brown", facecolor="None")
xticks = list(range(45))


ppy_urban.plot(ax=ax, color='grey', edgecolor='black')
ax.set_xlim(7,7.8)
ax.add_patch(bats_area)
ax.legend(labels = ["Pygmaeus AOI"],loc="lower right")
ax.set_ylim(45.1, 45.62)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# Display the map
plt.savefig('pipistrellus pygmaeus and urban areas', dpi=250, bbox_inches='tight')
plt.show()

# %%
a =list(range(0,10,2))
print(a)
# Out:
# [0, 2, 4, 6, 8]

# %%
bats_bbox
# Out:
# array([[45.4,  7.1],
#        [45.6,  7.1],
#        [45.6,  7.7],
#        [45.4,  7.7]])
